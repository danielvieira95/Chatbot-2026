# %%
# instalação  da Biblioteca Groq
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %%
# importando a biblioteca do google colab
from google.colab import userdata
chat_api = userdata.get('api_chat26') # armazenando a chave da api

# %%
#chat_api

# %%
from groq import Groq # importando a biblioteca Groq

# %%
client = Groq(api_key=chat_api) # cria um cliente do Groq para realizar as
# requisições para a api
# Faz a solicitação para o modelo
completion =client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
          "role":"system","content":"Você é um assistente de agricultor"
        },
        {
            "role":"user","content":"Qual a semente é indicada para \n o solo arenoso em maio ?"
        }
    ],
    temperature =0,
    max_tokens=1024,
    top_p=1,
    stream = False,

)
#Exibe a resposta gerada

print(completion.choices[0].message.content)
# Out:
# Para solo arenoso em maio, é importante escolher culturas que sejam resistentes à seca e possam se adaptar bem a esse tipo de solo. Aqui estão algumas opções de sementes que podem ser indicadas:
#
# 1. **Milho**: O milho é uma cultura que pode se adaptar bem a solos arenosos, desde que haja irrigação adequada. É uma boa opção para maio, pois é uma época de clima quente e seco, que favorece o crescimento do milho.
# 2. **Feijão**: O feijão é outra cultura que pode se adaptar bem a solos arenosos. Existem várias variedades de feijão que são resistentes à seca e podem ser plantadas em maio.
# 3. **Cenoura**: A cenoura é uma cultura que pode se adaptar bem a solos arenosos e é uma boa opção para maio. Ela é fácil de cultivar e pode ser colhida em cerca de 60 dias.
# 4. **Pepino**: O pepino é uma cultura que pode se adaptar bem a solos arenosos e é uma boa opção para maio. Ele é fácil de cultivar e pode ser colhido em cerca de 50 dias.
# 5. **Abobrinha**: A abobrinha é uma cultura que pode se adaptar bem a solos arenosos e é uma boa opção para maio. Ela é fácil de cultivar e pode ser colhida em cerca de 40 dias.
#
# Lembre-se de que, antes de plantar, é importante preparar o solo adequadamente, adicionando matéria orgânica e fertilizantes para melhorar a fertilidade e a retenção de água do solo.
#
# Além disso, é importante considerar as seguintes dicas para cultivar em solo arenoso:
#
# * Use irrigação adequada para evitar a seca do solo.
# * Adicione matéria orgânica ao solo para melhorar a retenção de água e a fertilidade.
# * Use fertilizantes adequados para a cultura escolhida.
# * Plante em épocas de clima mais fresco para evitar o estresse térmico.
#
# Espero que essas informações sejam úteis! Se tiver mais alguma dúvida, sinta-se à vontade para perguntar.

# %%
# Solicitando para que o usuario do chat digite sua pergunta
user_prompt = input('Digite sua pergunta:')
client = Groq(api_key=chat_api) # cria um cliente do Groq para realizar as
# requisições para a api
# Faz a solicitação para o modelo
completion =client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
          "role":"system","content":"Você é um assistente de agricultor"
        },
        {
            "role":"user","content":user_prompt
        }
    ],
    temperature =0.5,
    max_tokens=1024,
    top_p=1,
    stream = False,

)
#Exibe a resposta gerada
print("\n Resposta do assistente: \n ")
print(completion.choices[0].message.content)

# %%
# Solicitando para que o usuario do chat digite sua pergunta
user_prompt = input('Digite sua pergunta:')
client = Groq(api_key=chat_api) # cria um cliente do Groq para realizar as
# requisições para a api
# Faz a solicitação para o modelo
completion =client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
          "role":"system","content":"Você é um assistente de agricultor"
        },
        {
            "role":"user","content":user_prompt
        }
    ],
    temperature =0.7,
    max_tokens=1024,
    top_p=1,
    stream = False,

)
#Exibe a resposta gerada
print("\n Resposta do assistente: \n ")
print(completion.choices[0].message.content)

# %%
client = Groq(api_key=chat_api) # cria um cliente do Groq para realizar as
while True:

  # Solicitando para que o usuario do chat digite sua pergunta
  user_prompt = input('\n Digite sua pergunta sobre agricultura ou digite 15 para sair:')
  if user_prompt.strip()=="15":
    print('Encerrando o chatbot')

    break
  else:
    # requisições para a api
  # Faz a solicitação para o modelo
    completion =client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
          "role":"system","content":"Você é um assistente de agricultor"
        },
        {
            "role":"user","content":user_prompt
        }
      ],
      temperature =0.5,
      max_tokens=1024,
      top_p=1,
      stream = False,
)
      #Exibe a resposta gerada
  print("\n Resposta do assistente: \n ")
  print(completion.choices[0].message.content)
# Out:
#  Digite sua pergunta sobre agricultura ou digite 15 para sair:solo para plantar morangis
#
#  Resposta do assistente:
#
# Que delícia! Plantar morangos é um processo simples e prazeroso. Aqui estão algumas dicas para você criar um solo ideal para plantar morangos:
#
# **Requisitos do solo:**
#
# 1. **Acidez**: Os morangos preferem solos ácidos, com pH entre 5,5 e 6,5.
# 2. **Fertilidade**: O solo deve ser rico em nutrientes, especialmente potássio, cálcio e magnésio.
# 3. **Drainagem**: O solo deve ter boa drenagem para evitar a formação de musgo e doenças.
#
# **Preparo do solo:**
#
# 1. **Escolha um local**: Escolha um local com sol pleno e bem ventilado.
# 2. **Remova a vegetação**: Remova qualquer vegetação existente no local.
# 3. **Adube o solo**: Adube o solo com 10-15 cm de matéria orgânica, como esterco ou composto.
# 4. **Adicione fertilizantes**: Adicione fertilizantes específicos para morangos, como potássio e cálcio.
# 5. **Amoare o solo**: Amoare o solo para que as partículas sejam finas e uniformes.
#
# **Dicas adicionais:**
#
# 1. **Use plantas de cobertura**: Use plantas de cobertura, como alfafa ou trigo, para evitar a erosão do solo e melhorar a fertilidade.
# 2. **Não use herbicidas**: Não use herbicidas, pois podem danificar as plantas de morangos.
# 3. **Regue regularmente**: Regue regularmente, mas evite o excesso de água, que pode causar doenças.
#
# **Preparo da plantação:**
#
# 1. **Escolha as plantas**: Escolha plantas de morangos resistentes às doenças e pragas.
# 2. **Plante as plantas**: Plante as plantas de morangos a uma distância de 60-90 cm entre si.
# 3. **Cuide das plantas**: Cuidado das plantas, regando e fertilizando regularmente.
#
# Lembre-se de que a plantação de morangos é um processo contínuo, e é importante cuidar das plantas regularmente para obter um bom resultado. Boa sorte!
#
#  Digite sua pergunta sobre agricultura ou digite 15 para sair:15
# Encerrando o chatbot
