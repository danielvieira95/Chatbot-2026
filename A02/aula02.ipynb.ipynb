# %%
# !pip install llama_index.llms.groq

# %%
from google.colab import userdata
GROQ_API = userdata.get('api_groq26')

# %%
from llama_index.llms.groq import Groq

# %%
llm = Groq(model='llama-3.3-70b-versatile', api_key=GROQ_API)
response = llm.complete('Qual é a substância que dá o aroma do alecrim?')
response
paragrafos = response.text.split("\n\n")
for paragrafo in paragrafos:
    print(paragrafo)
    print()
# Out:
# A substância que dá o aroma do alecrim é o carvona. No entanto, o composto principal responsável pelo aroma característico do alecrim é o timol, um fenol monoterpeno. O timol é um óleo essencial encontrado nas folhas do alecrim (Rosmarinus officinalis) e é responsável pelo seu aroma e sabor únicos. Além disso, o alecrim também contém outros compostos, como o borneol, o canfeno e o cinolo, que contribuem para o seu aroma complexo.
